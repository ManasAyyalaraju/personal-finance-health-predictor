# %% [markdown]
# # Personal Finance Health Predictor - Data Exploration
#
# This notebook explores the datasets used for credit risk prediction, fraud detection, and customer segmentation.

# %% [markdown]
# # Project Setup and Data Loading

# %%
# Setup: Set working directory to project root
import os
import sys
from pathlib import Path

# Get the project root directory (parent of notebooks folder)
# In Jupyter, we can use the current working directory or navigate up from notebooks/
notebook_dir = Path.cwd()
if notebook_dir.name == 'notebooks':
    project_root = notebook_dir.parent
    os.chdir(project_root)
    print(f"✓ Working directory set to: {os.getcwd()}")
elif (notebook_dir / 'notebooks').exists():
    # Already in project root
    project_root = notebook_dir
    print(f"✓ Working directory: {os.getcwd()}")
else:
    # Try to find project root by looking for data/ or notebooks/ directory
    current = notebook_dir
    while current != current.parent:
        if (current / 'data').exists() or (current / 'notebooks').exists():
            project_root = current
            os.chdir(project_root)
            print(f"✓ Working directory set to: {os.getcwd()}")
            break
        current = current.parent
    else:
        print(f"⚠ Warning: Could not find project root. Current directory: {os.getcwd()}")
        print("Please ensure you're running from the project root or notebooks directory.")
# Out:
# ✓ Working directory: c:\Users\manas\Desktop\Projects\personal-finance-health-predictor

# %%
# Verify working directory
print(f"Current working directory: {os.getcwd()}")
print(f"Data directory exists: {os.path.exists('data/raw')}")
# Out:
# Current working directory: c:\Users\manas\Desktop\Projects\personal-finance-health-predictor
# Data directory exists: True

# %%
# List data directory contents
if os.path.exists('data/raw'):
    print("Data files in data/raw/:")
    for item in os.listdir('data/raw'):
        print(f"  - {item}")
else:
    print("⚠ Warning: data/raw directory not found. Please ensure data files are in the correct location.")
# Out:
# Data files in data/raw/:
#   - .gitkeep
#   - accepted
#   - creditcard.csv
#   - german_credit_data.csv
#   - rejected

# %%
# Install required packages (if not already installed)
# Uncomment the line below if you need to install packages
# !pip install imbalanced-learn xgboost shap -q

# Note: It's recommended to use a virtual environment and install from requirements.txt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Verify setup
print(f"✓ Working directory: {os.getcwd()}")
print(f"✓ Python version: {sys.version}")
# Out:
# ✓ Working directory: c:\Users\manas\Desktop\Projects\personal-finance-health-predictor
# ✓ Python version: 3.12.4 (tags/v3.12.4:8e8a4ba, Jun  6 2024, 19:30:16) [MSC v.1940 64 bit (AMD64)]

# %%
# Data Download Instructions
# 
# To download the datasets, you have two options:
#
# Option 1: Manual Download
# - German Credit: https://www.kaggle.com/datasets/uciml/german-credit
# - Lending Club: https://www.kaggle.com/datasets/wordsforthewise/lending-club
# - Credit Card Fraud: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# 
# Option 2: Using Kaggle API (requires kaggle.json in ~/.kaggle/)
# Uncomment the lines below if you have Kaggle API set up:
#
# import subprocess
# import os
# 
# # Ensure data directory exists
# os.makedirs('data/raw', exist_ok=True)
# 
# # Download datasets
# subprocess.run(['kaggle', 'datasets', 'download', '-d', 'uciml/german-credit', 
#                '-p', 'data/raw/', '--unzip'], check=True)
# subprocess.run(['kaggle', 'datasets', 'download', '-d', 'wordsforthewise/lending-club', 
#                '-p', 'data/raw/', '--unzip'], check=True)
# subprocess.run(['kaggle', 'datasets', 'download', '-d', 'mlg-ulb/creditcardfraud', 
#                '-p', 'data/raw/', '--unzip'], check=True)
# 
# print("✓ All datasets downloaded!")

# Check if data files exist
data_files = {
    'german_credit': 'data/raw/german_credit_data.csv',
    'lending_club': 'data/raw/accepted/accepted_2007_to_2018Q4.csv',
    'fraud_data': 'data/raw/creditcard.csv'
}

print("Checking for data files:")
for name, path in data_files.items():
    exists = os.path.exists(path)
    status = "✓" if exists else "✗"
    print(f"  {status} {name}: {path}")

if all(os.path.exists(path) for path in data_files.values()):
    print("\n✓ All required data files found!")
else:
    print("\n⚠ Some data files are missing. Please download them from Kaggle.")
# Out:
# Checking for data files:
#   ✓ german_credit: data/raw/german_credit_data.csv
#   ✓ lending_club: data/raw/accepted/accepted_2007_to_2018Q4.csv
#   ✓ fraud_data: data/raw/creditcard.csv
#
# ✓ All required data files found!

# %% [markdown]
# # Initial Data Exploration

# %% [markdown]
# German Credit Dataset Exploraton

# %%
german_credit = pd.read_csv('data/raw/german_credit_data.csv')

# %%
german_credit.head(10)
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
# 5           5   35    male    1    free             NaN              NaN
# 6           6   53    male    2     own      quite rich              NaN
# 7           7   35    male    3    rent          little         moderate
# 8           8   61    male    1     own            rich              NaN
# 9           9   28    male    3     own          little         moderate
#
#    Credit amount  Duration              Purpose
# 0           1169         6             radio/TV
# 1           5951        48             radio/TV
# ...

# %%
german_credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Sex               1000 non-null   object
#  3   Job               1000 non-null   int64
#  4   Housing           1000 non-null   object
#  5   Saving accounts   817 non-null    object
#  6   Checking account  606 non-null    object
#  7   Credit amount     1000 non-null   int64
#  8   Duration          1000 non-null   int64
#  9   Purpose           1000 non-null   object
# dtypes: int64(5), object(5)
# memory usage: 78.3+ KB

# %%
german_credit.shape
# Out:
# (1000, 10)

# %%
german_credit.dtypes
# Out:
# Unnamed: 0           int64
# Age                  int64
# Sex                 object
# Job                  int64
# Housing             object
# Saving accounts     object
# Checking account    object
# Credit amount        int64
# Duration             int64
# Purpose             object
# dtype: object

# %%
german_credit.isnull().sum()
# Out:
# Unnamed: 0            0
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# dtype: int64

# %%
german_credit.describe()
# Out:
#         Unnamed: 0          Age          Job  Credit amount     Duration
# count  1000.000000  1000.000000  1000.000000    1000.000000  1000.000000
# mean    499.500000    35.546000     1.904000    3271.258000    20.903000
# std     288.819436    11.375469     0.653614    2822.736876    12.058814
# min       0.000000    19.000000     0.000000     250.000000     4.000000
# 25%     249.750000    27.000000     2.000000    1365.500000    12.000000
# 50%     499.500000    33.000000     2.000000    2319.500000    18.000000
# 75%     749.250000    42.000000     2.000000    3972.250000    24.000000
# max     999.000000    75.000000     3.000000   18424.000000    72.000000

# %% [markdown]
# Lending Club Exploration

# %%
lending_club = pd.read_csv('data/raw/accepted/accepted_2007_to_2018Q4.csv',nrows=100000, low_memory=False)

# %%
lending_club.head(10)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
# 5  68426831        NaN    11950.0      11950.0          11950.0   36 months
# 6  68476668        NaN    20000.0      20000.0          20000.0   36 months
# 7  67275481        NaN    20000.0      20000.0          20000.0   36 months
# 8  68466926        NaN    10000.0      10000.0          10000.0   36 months
# 9  68616873        NaN     8000.0       8000.0           8000.0   36 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# ...

# %%
lending_club.shape
# Out:
# (100000, 151)

# %%
lending_club.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=151)

# %%
lending_club.isnull().sum()
# Out:
# id                            0
# member_id                100000
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
#                           ...
# settlement_status         97051
# settlement_date           97051
# settlement_amount         97051
# settlement_percentage     97051
# settlement_term           97051
# Length: 151, dtype: int64

# %% [markdown]
# Fraud Credit Card Data Exploration

# %%
fraud_data = pd.read_csv('data/raw/creditcard.csv')

# %%
fraud_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
fraud_data.shape
# Out:
# (284807, 31)

# %%
fraud_data.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
fraud_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %%
fraud_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
fraud_pct = fraud_data['Class'].mean() * 100
print(f"\n🚨 Fraud percentage: {fraud_pct:.3f}% (Highly imbalanced!)")
# Out:
# 🚨 Fraud percentage: 0.173% (Highly imbalanced!)

# %% [markdown]
# # Basic Data Visulization

# %% [markdown]
# German Credit Data Visualizations

# %%
# Create figure
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Left: Histogram with statistics
axes[0].hist(german_credit['Credit amount'], bins=40, color='#3498db',
             edgecolor='black', alpha=0.7)
axes[0].axvline(german_credit['Credit amount'].mean(), color='red',
                linestyle='--', linewidth=2.5, label=f'Mean: €{german_credit["Credit amount"].mean():.0f}')
axes[0].axvline(german_credit['Credit amount'].median(), color='orange',
                linestyle='--', linewidth=2.5, label=f'Median: €{german_credit["Credit amount"].median():.0f}')
axes[0].set_title('Credit Amount Distribution', fontsize=16, fontweight='bold')
axes[0].set_xlabel('Credit Amount (€)', fontsize=12)
axes[0].set_ylabel('Frequency', fontsize=12)
axes[0].legend(fontsize=11, loc='upper right')
axes[0].grid(alpha=0.3)

# Add statistics box
stats_text = f'Min: €{german_credit["Credit amount"].min():,.0f}\nMax: €{german_credit["Credit amount"].max():,.0f}\nStd Dev: €{german_credit["Credit amount"].std():.0f}'
axes[0].text(0.98, 0.65, stats_text, transform=axes[0].transAxes,
             fontsize=11, verticalalignment='top', horizontalalignment='right',
             bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

# Right: Box plot
axes[1].boxplot(german_credit['Credit amount'], vert=True,
                patch_artist=True,
                boxprops=dict(facecolor='#3498db', alpha=0.7),
                medianprops=dict(color='red', linewidth=2),
                whiskerprops=dict(linewidth=1.5),
                capprops=dict(linewidth=1.5))
axes[1].set_title('Credit Amount Box Plot', fontsize=16, fontweight='bold')
axes[1].set_ylabel('Credit Amount (€)', fontsize=12)
axes[1].grid(alpha=0.3, axis='y')

plt.tight_layout()

# Create results directory if it doesn't exist
os.makedirs('results/exploration', exist_ok=True)

# Save the figure
plt.savefig('results/exploration/day1_01_credit_amount_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 1 complete: Credit Amount Analysis")
# Out:
# ✓ Visualization 1 complete: Credit Amount Analysis

# %%
plt.figure(figsize=(12, 6))

# Get purpose counts and percentages
purpose_counts = german_credit['Purpose'].value_counts()
total = len(german_credit)

# Create horizontal bar chart
colors = plt.cm.Set3(range(len(purpose_counts)))
bars = plt.barh(range(len(purpose_counts)), purpose_counts.values,
                color=colors, edgecolor='black', linewidth=1.5)

# Customize
plt.yticks(range(len(purpose_counts)), purpose_counts.index, fontsize=11)
plt.xlabel('Number of Loans', fontsize=13, fontweight='bold')
plt.ylabel('Loan Purpose', fontsize=13, fontweight='bold')
plt.title('Loan Purpose Distribution - What Are People Borrowing For?',
          fontsize=16, fontweight='bold', pad=20)
plt.grid(alpha=0.3, axis='x')

# Add value labels with percentages
for i, (count, bar) in enumerate(zip(purpose_counts.values, bars)):
    percentage = (count / total) * 100
    plt.text(count + 10, i, f'{count} ({percentage:.1f}%)',
             va='center', fontweight='bold', fontsize=10)

# Add total at bottom
plt.text(0.98, 0.02, f'Total Loans: {total:,}',
         transform=plt.gca().transAxes, fontsize=11,
         verticalalignment='bottom', horizontalalignment='right',
         bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_02_loan_purpose_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 2 complete: Loan Purpose Distribution")
# Out:
# ✓ Visualization 2 complete: Loan Purpose Distribution

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# Create scatter plot with size based on age
scatter = ax.scatter(german_credit['Duration'],
                     german_credit['Credit amount'],
                     s=german_credit['Age']*3,  # Size based on age
                     alpha=0.6,
                     c=german_credit['Age'],  # Color based on age
                     cmap='viridis',
                     edgecolors='black',
                     linewidth=0.5)

# Add colorbar for age
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Age (years)', fontsize=12, fontweight='bold')

# Add trend line
z = np.polyfit(german_credit['Duration'], german_credit['Credit amount'], 1)
p = np.poly1d(z)
plt.plot(german_credit['Duration'], p(german_credit['Duration']),
         "r--", linewidth=3, alpha=0.8, label='Trend Line')

# Titles and labels
ax.set_title('Loan Duration vs Credit Amount\n(Bubble size = Age)',
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Duration (months)', fontsize=13, fontweight='bold')
ax.set_ylabel('Credit Amount (€)', fontsize=13, fontweight='bold')
ax.grid(alpha=0.3)
ax.legend(fontsize=11)

# Calculate and display correlation
correlation = german_credit['Duration'].corr(german_credit['Credit amount'])
ax.text(0.02, 0.98, f'Correlation: {correlation:.3f}',
        transform=ax.transAxes, fontsize=12, fontweight='bold',
        verticalalignment='top',
        bbox=dict(boxstyle='round', facecolor='yellow', alpha=0.8))

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_03_duration_vs_amount.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 3 complete: Duration vs Amount Relationship")
print(f"  Correlation coefficient: {correlation:.3f}")
# Out:
# ✓ Visualization 3 complete: Duration vs Amount Relationship
#   Correlation coefficient: 0.625

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 11))
fig.suptitle('German Credit Dataset - Demographics Overview',
             fontsize=18, fontweight='bold', y=0.995)

# Panel 1: Age Distribution
axes[0, 0].hist(german_credit['Age'], bins=30, color='#3498db',
                edgecolor='black', alpha=0.7)
axes[0, 0].axvline(german_credit['Age'].mean(), color='red',
                   linestyle='--', linewidth=2,
                   label=f'Mean: {german_credit["Age"].mean():.1f}')
axes[0, 0].axvline(german_credit['Age'].median(), color='green',
                   linestyle='--', linewidth=2,
                   label=f'Median: {german_credit["Age"].median():.1f}')
axes[0, 0].set_title('Age Distribution', fontsize=14, fontweight='bold')
axes[0, 0].set_xlabel('Age (years)', fontsize=11)
axes[0, 0].set_ylabel('Frequency', fontsize=11)
axes[0, 0].legend()
axes[0, 0].grid(alpha=0.3)

# Panel 2: Gender Distribution
sex_counts = german_credit['Sex'].value_counts()
colors_sex = ['#3498db', '#e74c3c']
wedges, texts, autotexts = axes[0, 1].pie(sex_counts.values,
                                           labels=sex_counts.index,
                                           autopct='%1.1f%%',
                                           colors=colors_sex,
                                           startangle=90,
                                           explode=(0.05, 0.05),
                                           textprops={'fontsize': 12, 'fontweight': 'bold'})
axes[0, 1].set_title('Gender Distribution', fontsize=14, fontweight='bold')

# Panel 3: Housing Status
housing_counts = german_credit['Housing'].value_counts()
colors_housing = ['#2ecc71', '#f39c12', '#e74c3c']
housing_counts.plot(kind='bar', ax=axes[1, 0],
                    color=colors_housing[:len(housing_counts)],
                    edgecolor='black', width=0.7)
axes[1, 0].set_title('Housing Status', fontsize=14, fontweight='bold')
axes[1, 0].set_xlabel('Housing Type', fontsize=11)
axes[1, 0].set_ylabel('Count', fontsize=11)
axes[1, 0].tick_params(axis='x', rotation=45)

# Add value labels
for i, v in enumerate(housing_counts.values):
    axes[1, 0].text(i, v + 10, f'{v}\n({v/len(german_credit)*100:.1f}%)',
                    ha='center', fontweight='bold', fontsize=10)

# Panel 4: Job Distribution
job_counts = german_credit['Job'].value_counts().sort_index()
colors_job = ['#e74c3c', '#f39c12', '#2ecc71', '#3498db']
job_counts.plot(kind='bar', ax=axes[1, 1],
                color=colors_job, edgecolor='black', width=0.7)
axes[1, 1].set_title('Job Category Distribution', fontsize=14, fontweight='bold')
axes[1, 1].set_xlabel('Job Code', fontsize=11)
axes[1, 1].set_ylabel('Count', fontsize=11)
axes[1, 1].tick_params(axis='x', rotation=0)

# Add value labels
for i, v in enumerate(job_counts.values):
    axes[1, 1].text(i, v + 10, f'{v}\n({v/len(german_credit)*100:.1f}%)',
                    ha='center', fontweight='bold', fontsize=10)

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_04_demographics_overview.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 4 complete: Demographics Overview (4-panel)")
# Out:
# ✓ Visualization 4 complete: Demographics Overview (4-panel)

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Left: Correlation Heatmap
numerical_cols = ['Age', 'Job', 'Credit amount', 'Duration']
corr_matrix = german_credit[numerical_cols].corr()

sns.heatmap(corr_matrix, annot=True, fmt='.3f', cmap='RdYlGn',
            center=0, square=True, linewidths=3, cbar_kws={"shrink": 0.8},
            vmin=-1, vmax=1, annot_kws={'fontsize': 13, 'fontweight': 'bold'},
            ax=axes[0])
axes[0].set_title('Feature Correlation Heatmap', fontsize=15, fontweight='bold', pad=15)

# Right: Average Credit Amount by Purpose and Housing
pivot_data = german_credit.groupby(['Purpose', 'Housing'])['Credit amount'].mean().unstack()

sns.heatmap(pivot_data, annot=True, fmt='.0f', cmap='YlOrRd',
            linewidths=2, cbar_kws={"shrink": 0.8, "label": "Avg Credit (€)"},
            annot_kws={'fontsize': 9}, ax=axes[1])
axes[1].set_title('Average Credit Amount by Purpose & Housing',
                  fontsize=15, fontweight='bold', pad=15)
axes[1].set_xlabel('Housing Type', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Loan Purpose', fontsize=12, fontweight='bold')
plt.setp(axes[1].get_xticklabels(), rotation=45, ha='right')
plt.setp(axes[1].get_yticklabels(), rotation=0)

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_05_financial_profile_heatmaps.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 5 complete: Financial Profile Heatmaps")

# Print key insights
print("\n📊 Key Insights:")
print(f"  • Strongest correlation: Duration & Credit Amount ({corr_matrix.loc['Duration', 'Credit amount']:.3f})")
print(f"  • Age range: {german_credit['Age'].min()} - {german_credit['Age'].max()} years")
print(f"  • Most common purpose: {german_credit['Purpose'].mode()[0]}")
print(f"  • Average loan: €{german_credit['Credit amount'].mean():.2f}")
# Out:
# ✓ Visualization 5 complete: Financial Profile Heatmaps
#
# 📊 Key Insights:
#   • Strongest correlation: Duration & Credit Amount (0.625)
#   • Age range: 19 - 75 years
#   • Most common purpose: car
#   • Average loan: €3271.26

# %% [markdown]
# Lending Club Visulization

# %%
plt.figure(figsize=(14, 8))

# Get loan status counts
status_counts = lending_club['loan_status'].value_counts()
total_loans = len(lending_club)

# Define color scheme (green for good, red for bad, yellow for ongoing)
color_map = {
    'Fully Paid': '#2ecc71',
    'Current': '#3498db',
    'Charged Off': '#e74c3c',
    'Late (31-120 days)': '#f39c12',
    'In Grace Period': '#f39c12',
    'Late (16-30 days)': '#e67e22',
    'Default': '#c0392b',
    'Does not meet the credit policy. Status:Fully Paid': '#27ae60',
    'Does not meet the credit policy. Status:Charged Off': '#e74c3c'
}

colors = [color_map.get(status, '#95a5a6') for status in status_counts.index]

# Create bar chart
bars = plt.bar(range(len(status_counts)), status_counts.values,
               color=colors, edgecolor='black', linewidth=1)

# Customize
plt.xticks(range(len(status_counts)), status_counts.index,
           rotation=45, ha='right', fontsize=10)
plt.ylabel('Number of Loans', fontsize=13, fontweight='bold')
plt.title('Lending Club: Loan Status Distribution\n(Sample of 100,000 loans)',
          fontsize=16, fontweight='bold', pad=20)
plt.grid(alpha=0.3, axis='y')

# Add value labels with percentages
for i, (status, count) in enumerate(zip(status_counts.index, status_counts.values)):
    percentage = (count / total_loans) * 100
    plt.text(i, count + max(status_counts)*0.01,
             f'{count:,}\n({percentage:.1f}%)',
             ha='center', fontweight='bold', fontsize=9)

# Add summary statistics box
fully_paid = status_counts.get('Fully Paid', 0)
charged_off = status_counts.get('Charged Off', 0)
default_rate = (charged_off / (fully_paid + charged_off) * 100) if (fully_paid + charged_off) > 0 else 0

summary_text = f'Default Rate: {default_rate:.2f}%\nFully Paid: {fully_paid:,}\nCharged Off: {charged_off:,}'
plt.text(0.02, 0.98, summary_text, transform=plt.gca().transAxes,
         fontsize=11, verticalalignment='top', fontweight='bold',
         bbox=dict(boxstyle='round', facecolor='lightyellow', alpha=0.9))

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_06_lending_club_loan_status.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 1 complete: Loan Status Distribution")
print(f"  • Default Rate: {default_rate:.2f}%")
# Out:
# ✓ Visualization 1 complete: Loan Status Distribution
#   • Default Rate: 20.03%

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 12))
fig.suptitle('Interest Rate Analysis by Risk Grade',
             fontsize=18, fontweight='bold', y=0.995)

# Panel 1: Distribution by Grade (Violin Plot)
grade_order = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
grades_present = [g for g in grade_order if g in lending_club['grade'].unique()]

sns.violinplot(data=lending_club[lending_club['grade'].isin(grades_present)],
               x='grade', y='int_rate', order=grades_present,
               palette='RdYlGn_r', ax=axes[0, 0])
axes[0, 0].set_title('Interest Rate Distribution by Grade',
                     fontsize=14, fontweight='bold')
axes[0, 0].set_xlabel('Loan Grade', fontsize=12, fontweight='bold')
axes[0, 0].set_ylabel('Interest Rate (%)', fontsize=12, fontweight='bold')
axes[0, 0].grid(alpha=0.3, axis='y')

# Panel 2: Average Interest Rate by Grade (Bar Chart)
avg_rate_by_grade = lending_club.groupby('grade')['int_rate'].mean().reindex(grades_present)
colors_grade = ['#2ecc71', '#27ae60', '#f39c12', '#e67e22', '#e74c3c', '#c0392b', '#8e44ad']

bars = axes[0, 1].bar(range(len(avg_rate_by_grade)), avg_rate_by_grade.values,
                       color=colors_grade[:len(avg_rate_by_grade)],
                       edgecolor='black', linewidth=1.5)
axes[0, 1].set_xticks(range(len(avg_rate_by_grade)))
axes[0, 1].set_xticklabels(avg_rate_by_grade.index, fontsize=11)
axes[0, 1].set_title('Average Interest Rate by Grade',
                     fontsize=14, fontweight='bold')
axes[0, 1].set_xlabel('Loan Grade', fontsize=12, fontweight='bold')
axes[0, 1].set_ylabel('Average Interest Rate (%)', fontsize=12, fontweight='bold')
axes[0, 1].grid(alpha=0.3, axis='y')

# Add value labels
for i, v in enumerate(avg_rate_by_grade.values):
    axes[0, 1].text(i, v + 0.3, f'{v:.2f}%', ha='center', fontweight='bold', fontsize=10)

# Panel 3: Overall Interest Rate Distribution
axes[1, 0].hist(lending_club['int_rate'].dropna(), bins=50,
                color='#3498db', edgecolor='black', alpha=0.7)
axes[1, 0].axvline(lending_club['int_rate'].mean(), color='red',
                   linestyle='--', linewidth=2.5,
                   label=f'Mean: {lending_club["int_rate"].mean():.2f}%')
axes[1, 0].axvline(lending_club['int_rate'].median(), color='green',
                   linestyle='--', linewidth=2.5,
                   label=f'Median: {lending_club["int_rate"].median():.2f}%')
axes[1, 0].set_title('Overall Interest Rate Distribution',
                     fontsize=14, fontweight='bold')
axes[1, 0].set_xlabel('Interest Rate (%)', fontsize=12, fontweight='bold')
axes[1, 0].set_ylabel('Frequency', fontsize=12, fontweight='bold')
axes[1, 0].legend(fontsize=11)
axes[1, 0].grid(alpha=0.3)

# Panel 4: Loan Count by Grade
grade_counts = lending_club['grade'].value_counts().reindex(grades_present)
axes[1, 1].bar(range(len(grade_counts)), grade_counts.values,
               color=colors_grade[:len(grade_counts)],
               edgecolor='black', linewidth=1.5)
axes[1, 1].set_xticks(range(len(grade_counts)))
axes[1, 1].set_xticklabels(grade_counts.index, fontsize=11)
axes[1, 1].set_title('Loan Volume by Grade', fontsize=14, fontweight='bold')
axes[1, 1].set_xlabel('Loan Grade', fontsize=12, fontweight='bold')
axes[1, 1].set_ylabel('Number of Loans', fontsize=12, fontweight='bold')
axes[1, 1].grid(alpha=0.3, axis='y')

# Add percentage labels
for i, v in enumerate(grade_counts.values):
    pct = (v / grade_counts.sum()) * 100
    axes[1, 1].text(i, v + max(grade_counts)*0.01,
                    f'{v:,}\n({pct:.1f}%)',
                    ha='center', fontweight='bold', fontsize=9)

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_07_interest_rate_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 2 complete: Interest Rate Analysis")
print(f"  • Average rate: {lending_club['int_rate'].mean():.2f}%")
print(f"  • Rate range: {lending_club['int_rate'].min():.2f}% - {lending_club['int_rate'].max():.2f}%")
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_29608\1149888472.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=lending_club[lending_club['grade'].isin(grades_present)],
# ✓ Visualization 2 complete: Interest Rate Analysis
#   • Average rate: 12.20%
#   • Rate range: 5.32% - 28.99%

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8))

# Filter outliers for better visualization
filtered_data = lending_club[
    (lending_club['annual_inc'] < 200000) &
    (lending_club['loan_amnt'] < 40000) &
    (lending_club['annual_inc'].notna()) &
    (lending_club['loan_amnt'].notna())
].copy()

# Calculate loan-to-income ratio
filtered_data['loan_to_income'] = filtered_data['loan_amnt'] / filtered_data['annual_inc']

# Left: Scatter plot with density
scatter = axes[0].scatter(filtered_data['annual_inc'],
                          filtered_data['loan_amnt'],
                          c=filtered_data['int_rate'],
                          cmap='RdYlGn_r',
                          alpha=0.4,
                          s=20,
                          edgecolors='none')

# Add reference lines
x_line = np.linspace(0, 200000, 100)
axes[0].plot(x_line, x_line * 0.25, 'r--', linewidth=2,
             alpha=0.7, label='Loan = 25% of Income')
axes[0].plot(x_line, x_line * 0.50, 'orange', linestyle='--',
             linewidth=2, alpha=0.7, label='Loan = 50% of Income')

axes[0].set_title('Annual Income vs Loan Amount\n(Colored by Interest Rate)',
                  fontsize=14, fontweight='bold')
axes[0].set_xlabel('Annual Income ($)', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Loan Amount ($)', fontsize=12, fontweight='bold')
axes[0].legend(fontsize=10)
axes[0].grid(alpha=0.3)

# Add colorbar
cbar = plt.colorbar(scatter, ax=axes[0])
cbar.set_label('Interest Rate (%)', fontsize=11, fontweight='bold')

# Right: Loan-to-Income Ratio Distribution
axes[1].hist(filtered_data['loan_to_income'][filtered_data['loan_to_income'] < 1],
             bins=50, color='#9b59b6', edgecolor='black', alpha=0.7)
axes[1].axvline(filtered_data['loan_to_income'].median(), color='red',
                linestyle='--', linewidth=2.5,
                label=f'Median: {filtered_data["loan_to_income"].median():.2%}')
axes[1].axvline(0.25, color='orange', linestyle=':', linewidth=2,
                label='25% threshold', alpha=0.7)
axes[1].axvline(0.50, color='red', linestyle=':', linewidth=2,
                label='50% threshold', alpha=0.7)

axes[1].set_title('Loan-to-Income Ratio Distribution',
                  fontsize=14, fontweight='bold')
axes[1].set_xlabel('Loan Amount / Annual Income', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Frequency', fontsize=12, fontweight='bold')
axes[1].legend(fontsize=10)
axes[1].grid(alpha=0.3)

# Add statistics
stats_text = f'Mean: {filtered_data["loan_to_income"].mean():.2%}\nMedian: {filtered_data["loan_to_income"].median():.2%}\n>50%: {(filtered_data["loan_to_income"] > 0.5).sum():,} loans'
axes[1].text(0.98, 0.97, stats_text, transform=axes[1].transAxes,
             fontsize=10, verticalalignment='top', horizontalalignment='right',
             bbox=dict(boxstyle='round', facecolor='lightyellow', alpha=0.9))

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_08_income_vs_loan_amount.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 3 complete: Income vs Loan Amount")
print(f"  • Median loan-to-income: {filtered_data['loan_to_income'].median():.2%}")
print(f"  • Loans >50% of income: {(filtered_data['loan_to_income'] > 0.5).sum():,}")
# Out:
# ✓ Visualization 3 complete: Income vs Loan Amount
#   • Median loan-to-income: 21.00%
#   • Loans >50% of income: 116

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 12))
fig.suptitle('Debt-to-Income (DTI) Ratio Analysis - Key Credit Risk Indicator',
             fontsize=18, fontweight='bold', y=0.995)

# Filter DTI outliers
dti_filtered = lending_club[lending_club['dti'] < 50].copy()

# Panel 1: DTI Distribution
axes[0, 0].hist(dti_filtered['dti'].dropna(), bins=50,
                color='#34495e', edgecolor='black', alpha=0.7)
axes[0, 0].axvline(dti_filtered['dti'].mean(), color='red',
                   linestyle='--', linewidth=2.5,
                   label=f'Mean: {dti_filtered["dti"].mean():.2f}%')
axes[0, 0].axvline(dti_filtered['dti'].median(), color='green',
                   linestyle='--', linewidth=2.5,
                   label=f'Median: {dti_filtered["dti"].median():.2f}%')
axes[0, 0].axvline(36, color='orange', linestyle=':', linewidth=2,
                   label='43% threshold (high risk)', alpha=0.7)

axes[0, 0].set_title('DTI Ratio Distribution', fontsize=14, fontweight='bold')
axes[0, 0].set_xlabel('Debt-to-Income Ratio (%)', fontsize=12, fontweight='bold')
axes[0, 0].set_ylabel('Frequency', fontsize=12, fontweight='bold')
axes[0, 0].legend(fontsize=10)
axes[0, 0].grid(alpha=0.3)

# Panel 2: DTI by Loan Grade
grade_order = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
grades_present = [g for g in grade_order if g in dti_filtered['grade'].unique()]

sns.boxplot(data=dti_filtered[dti_filtered['grade'].isin(grades_present)],
            x='grade', y='dti', order=grades_present,
            palette='RdYlGn_r', ax=axes[0, 1])
axes[0, 1].set_title('DTI Distribution by Loan Grade',
                     fontsize=14, fontweight='bold')
axes[0, 1].set_xlabel('Loan Grade', fontsize=12, fontweight='bold')
axes[0, 1].set_ylabel('DTI Ratio (%)', fontsize=12, fontweight='bold')
axes[0, 1].grid(alpha=0.3, axis='y')

# Panel 3: DTI vs Interest Rate
sample_data = dti_filtered.sample(n=min(5000, len(dti_filtered)), random_state=42)
axes[1, 0].scatter(sample_data['dti'], sample_data['int_rate'],
                   alpha=0.3, s=20, c='#3498db', edgecolors='none')

# Add trend line
z = np.polyfit(sample_data['dti'].dropna(),
               sample_data['int_rate'].dropna(), 1)
p = np.poly1d(z)
x_line = np.linspace(sample_data['dti'].min(), sample_data['dti'].max(), 100)
axes[1, 0].plot(x_line, p(x_line), 'r--', linewidth=2.5,
                alpha=0.8, label='Trend Line')

axes[1, 0].set_title('DTI vs Interest Rate', fontsize=14, fontweight='bold')
axes[1, 0].set_xlabel('DTI Ratio (%)', fontsize=12, fontweight='bold')
axes[1, 0].set_ylabel('Interest Rate (%)', fontsize=12, fontweight='bold')
axes[1, 0].legend(fontsize=10)
axes[1, 0].grid(alpha=0.3)

# Calculate correlation
correlation = sample_data[['dti', 'int_rate']].corr().iloc[0, 1]
axes[1, 0].text(0.02, 0.98, f'Correlation: {correlation:.3f}',
                transform=axes[1, 0].transAxes, fontsize=11, fontweight='bold',
                verticalalignment='top',
                bbox=dict(boxstyle='round', facecolor='yellow', alpha=0.8))

# Panel 4: DTI Risk Categories
dti_categories = pd.cut(dti_filtered['dti'],
                        bins=[0, 20, 36, 43, 100],
                        labels=['Low (<20%)', 'Moderate (20-36%)',
                               'High (36-43%)', 'Very High (>43%)'])
dti_cat_counts = dti_categories.value_counts()

colors_dti = ['#2ecc71', '#f39c12', '#e67e22', '#e74c3c']
dti_cat_counts.plot(kind='bar', ax=axes[1, 1], color=colors_dti,
                    edgecolor='black', linewidth=1.5)
axes[1, 1].set_title('Loan Distribution by DTI Risk Category',
                     fontsize=14, fontweight='bold')
axes[1, 1].set_xlabel('DTI Risk Category', fontsize=12, fontweight='bold')
axes[1, 1].set_ylabel('Number of Loans', fontsize=12, fontweight='bold')
axes[1, 1].tick_params(axis='x', rotation=45)
axes[1, 1].grid(alpha=0.3, axis='y')

# Add percentage labels
for i, v in enumerate(dti_cat_counts.values):
    pct = (v / dti_cat_counts.sum()) * 100
    axes[1, 1].text(i, v + max(dti_cat_counts)*0.01,
                    f'{v:,}\n({pct:.1f}%)',
                    ha='center', fontweight='bold', fontsize=9)

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_09_dti_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 4 complete: DTI Analysis")
print(f"  • Average DTI: {dti_filtered['dti'].mean():.2f}%")
print(f"  • High risk (>43%): {(dti_filtered['dti'] > 43).sum():,} loans")
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_29608\3591559901.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=dti_filtered[dti_filtered['grade'].isin(grades_present)],
# ✓ Visualization 4 complete: DTI Analysis
#   • Average DTI: 19.21%
#   • High risk (>43%): 29 loans

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 12))
fig.suptitle('Loan Purpose & Home Ownership Analysis',
             fontsize=18, fontweight='bold', y=0.995)

# Panel 1: Loan Purpose Distribution
purpose_counts = lending_club['purpose'].value_counts().head(10)
colors_purpose = plt.cm.Set3(range(len(purpose_counts)))

axes[0, 0].barh(range(len(purpose_counts)), purpose_counts.values,
                color=colors_purpose, edgecolor='black', linewidth=1.5)
axes[0, 0].set_yticks(range(len(purpose_counts)))
axes[0, 0].set_yticklabels(purpose_counts.index, fontsize=10)
axes[0, 0].set_title('Top 10 Loan Purposes', fontsize=14, fontweight='bold')
axes[0, 0].set_xlabel('Number of Loans', fontsize=12, fontweight='bold')
axes[0, 0].grid(alpha=0.3, axis='x')

# Add value labels
for i, v in enumerate(purpose_counts.values):
    pct = (v / len(lending_club)) * 100
    axes[0, 0].text(v + max(purpose_counts)*0.01, i,
                    f'{v:,} ({pct:.1f}%)',
                    va='center', fontweight='bold', fontsize=9)

# Panel 2: Average Loan Amount by Purpose
avg_loan_by_purpose = lending_club.groupby('purpose')['loan_amnt'].mean().sort_values(ascending=False).head(10)

axes[0, 1].barh(range(len(avg_loan_by_purpose)), avg_loan_by_purpose.values,
                color='#3498db', edgecolor='black', linewidth=1.5)
axes[0, 1].set_yticks(range(len(avg_loan_by_purpose)))
axes[0, 1].set_yticklabels(avg_loan_by_purpose.index, fontsize=10)
axes[0, 1].set_title('Average Loan Amount by Purpose', fontsize=14, fontweight='bold')
axes[0, 1].set_xlabel('Average Loan Amount ($)', fontsize=12, fontweight='bold')
axes[0, 1].grid(alpha=0.3, axis='x')

# Add value labels
for i, v in enumerate(avg_loan_by_purpose.values):
    axes[0, 1].text(v + max(avg_loan_by_purpose)*0.01, i,
                    f'${v:,.0f}',
                    va='center', fontweight='bold', fontsize=9)

# Panel 3: Home Ownership Distribution
home_counts = lending_club['home_ownership'].value_counts()
colors_home = ['#2ecc71', '#3498db', '#f39c12', '#e74c3c', '#9b59b6']

wedges, texts, autotexts = axes[1, 0].pie(home_counts.values,
                                           labels=home_counts.index,
                                           autopct='%1.1f%%',
                                           colors=colors_home[:len(home_counts)],
                                           startangle=90,
                                           explode=[0.05]*len(home_counts),
                                           textprops={'fontsize': 11, 'fontweight': 'bold'})
axes[1, 0].set_title('Home Ownership Distribution', fontsize=14, fontweight='bold')

# Panel 4: Heatmap - Purpose vs Home Ownership (Average Loan Amount)
top_purposes = lending_club['purpose'].value_counts().head(8).index
pivot_data = lending_club[lending_club['purpose'].isin(top_purposes)].groupby(
    ['purpose', 'home_ownership'])['loan_amnt'].mean().unstack(fill_value=0)

sns.heatmap(pivot_data, annot=True, fmt='.0f', cmap='YlOrRd',
            linewidths=2, cbar_kws={"label": "Avg Loan ($)"},
            annot_kws={'fontsize': 8}, ax=axes[1, 1])
axes[1, 1].set_title('Avg Loan Amount: Purpose × Home Ownership',
                     fontsize=14, fontweight='bold')
axes[1, 1].set_xlabel('Home Ownership', fontsize=12, fontweight='bold')
axes[1, 1].set_ylabel('Loan Purpose', fontsize=12, fontweight='bold')
plt.setp(axes[1, 1].get_xticklabels(), rotation=45, ha='right')
plt.setp(axes[1, 1].get_yticklabels(), rotation=0)

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_10_purpose_home_ownership.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 5 complete: Purpose & Home Ownership")
print(f"  • Most common purpose: {lending_club['purpose'].mode()[0]}")
print(f"  • Most common home status: {lending_club['home_ownership'].mode()[0]}")
# Out:
# ✓ Visualization 5 complete: Purpose & Home Ownership
#   • Most common purpose: debt_consolidation
#   • Most common home status: MORTGAGE

# %% [markdown]
# Fraud Data Visulizations

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 9))
fig.suptitle('Credit Card Fraud: The Class Imbalance Challenge',
             fontsize=18, fontweight='bold', y=1.02)

# Count fraud vs normal
fraud_counts = fraud_data['Class'].value_counts()
normal_count = fraud_counts[0]
fraud_count = fraud_counts[1]
fraud_rate = (fraud_count / len(fraud_data)) * 100

# Panel 1: Bar Chart (Linear Scale)
colors = ['#3498db', '#e74c3c']
bars = axes[0].bar(['Normal', 'Fraud'], fraud_counts.values,
                   color=colors, edgecolor='black', linewidth=2, width=0.6)

axes[0].set_title('Transaction Distribution (Linear Scale)',
                  fontsize=14, fontweight='bold')
axes[0].set_ylabel('Number of Transactions', fontsize=12, fontweight='bold')
axes[0].grid(alpha=0.3, axis='y')

# Add value labels
for i, (label, count) in enumerate(zip(['Normal', 'Fraud'], fraud_counts.values)):
    axes[0].text(i, count + max(fraud_counts)*0.02,
                 f'{count:,}\n({count/len(fraud_data)*100:.3f}%)',
                 ha='center', fontweight='bold', fontsize=11)

# Panel 2: Bar Chart (Log Scale)
axes[1].bar(['Normal', 'Fraud'], fraud_counts.values,
            color=colors, edgecolor='black', linewidth=2, width=0.6)
axes[1].set_yscale('log')
axes[1].set_title('Transaction Distribution (Log Scale)',
                  fontsize=14, fontweight='bold')
axes[1].set_ylabel('Number of Transactions (log scale)', fontsize=12, fontweight='bold')
axes[1].grid(alpha=0.3, axis='y')

# Add value labels
for i, count in enumerate(fraud_counts.values):
    axes[1].text(i, count * 1.2, f'{count:,}',
                 ha='center', fontweight='bold', fontsize=11)

# Panel 3: Pie Chart with Explosion
explode = (0, 0.3)  # Explode fraud slice
wedges, texts, autotexts = axes[2].pie(
    fraud_counts.values,
    labels=['Normal\nTransactions', 'Fraudulent\nTransactions'],
    autopct='%1.3f%%',
    colors=colors,
    explode=explode,
    startangle=90,
    textprops={'fontsize': 12, 'fontweight': 'bold'},
    shadow=True
)

# Make percentage text more visible
for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontsize(13)
    autotext.set_fontweight('bold')

axes[2].set_title('Percentage Breakdown', fontsize=14, fontweight='bold')

# Add statistics box
stats_text = f'Total Transactions: {len(fraud_data):,}\nNormal: {normal_count:,}\nFraud: {fraud_count:,}\n\nImbalance Ratio: {normal_count/fraud_count:.0f}:1\nFraud Rate: {fraud_rate:.3f}%'
fig.text(0.98, 0.02, stats_text, fontsize=11, fontweight='bold',
         verticalalignment='bottom', horizontalalignment='right',
         bbox=dict(boxstyle='round', facecolor='lightyellow', alpha=0.9))

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_11_fraud_class_imbalance.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 1 complete: Class Imbalance")
print(f"  • Imbalance ratio: {normal_count/fraud_count:.0f}:1")
print(f"  • This is why fraud detection is challenging!")
# Out:
# ✓ Visualization 1 complete: Class Imbalance
#   • Imbalance ratio: 578:1
#   • This is why fraud detection is challenging!

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 12))
fig.suptitle('Transaction Amount Patterns: Normal vs Fraudulent',
             fontsize=18, fontweight='bold', y=0.995)

# Separate data
normal_amounts = fraud_data[fraud_data['Class'] == 0]['Amount']
fraud_amounts = fraud_data[fraud_data['Class'] == 1]['Amount']

# Panel 1: Normal Transaction Distribution
axes[0, 0].hist(normal_amounts[normal_amounts < 1000], bins=100,
                color='#3498db', edgecolor='black', alpha=0.7)
axes[0, 0].axvline(normal_amounts.mean(), color='red', linestyle='--',
                   linewidth=2.5, label=f'Mean: €{normal_amounts.mean():.2f}')
axes[0, 0].axvline(normal_amounts.median(), color='green', linestyle='--',
                   linewidth=2.5, label=f'Median: €{normal_amounts.median():.2f}')
axes[0, 0].set_title('Normal Transactions (Amount < €1000)',
                     fontsize=14, fontweight='bold')
axes[0, 0].set_xlabel('Transaction Amount (€)', fontsize=12, fontweight='bold')
axes[0, 0].set_ylabel('Frequency', fontsize=12, fontweight='bold')
axes[0, 0].legend(fontsize=10)
axes[0, 0].grid(alpha=0.3)

# Panel 2: Fraud Transaction Distribution
axes[0, 1].hist(fraud_amounts, bins=50, color='#e74c3c',
                edgecolor='black', alpha=0.7)
axes[0, 1].axvline(fraud_amounts.mean(), color='darkred', linestyle='--',
                   linewidth=2.5, label=f'Mean: €{fraud_amounts.mean():.2f}')
axes[0, 1].axvline(fraud_amounts.median(), color='orange', linestyle='--',
                   linewidth=2.5, label=f'Median: €{fraud_amounts.median():.2f}')
axes[0, 1].set_title('Fraudulent Transactions (All Amounts)',
                     fontsize=14, fontweight='bold')
axes[0, 1].set_xlabel('Transaction Amount (€)', fontsize=12, fontweight='bold')
axes[0, 1].set_ylabel('Frequency', fontsize=12, fontweight='bold')
axes[0, 1].legend(fontsize=10)
axes[0, 1].grid(alpha=0.3)

# Panel 3: Box Plot Comparison
box_data = [normal_amounts[normal_amounts < 500], fraud_amounts]
bp = axes[1, 0].boxplot(box_data,
                        labels=['Normal\n(< €500)', 'Fraud\n(All)'],
                        patch_artist=True,
                        showfliers=False,  # Remove outliers for clarity
                        widths=0.6)

# Color the boxes
bp['boxes'][0].set_facecolor('#3498db')
bp['boxes'][0].set_alpha(0.7)
bp['boxes'][1].set_facecolor('#e74c3c')
bp['boxes'][1].set_alpha(0.7)

for median in bp['medians']:
    median.set_color('black')
    median.set_linewidth(2.5)

axes[1, 0].set_title('Amount Distribution Comparison\n(Outliers removed for clarity)',
                     fontsize=14, fontweight='bold')
axes[1, 0].set_ylabel('Transaction Amount (€)', fontsize=12, fontweight='bold')
axes[1, 0].grid(alpha=0.3, axis='y')

# Panel 4: Statistics Comparison Table
stats_comparison = pd.DataFrame({
    'Normal': normal_amounts.describe(),
    'Fraud': fraud_amounts.describe()
}).T

# Create table
table_data = [['Metric', 'Normal (€)', 'Fraud (€)', 'Difference']]
metrics = ['mean', 'std', 'min', '25%', '50%', '75%', 'max']
for metric in metrics:
    normal_val = stats_comparison.loc['Normal', metric]
    fraud_val = stats_comparison.loc['Fraud', metric]
    diff = fraud_val - normal_val
    diff_str = f'{diff:+.2f}' if metric != 'count' else '-'
    table_data.append(
        [metric.upper(),
         f'{normal_val:.2f}',
         f'{fraud_val:.2f}',
         diff_str]
    )

axes[1, 1].axis('tight')
axes[1, 1].axis('off')

table = axes[1, 1].table(cellText=table_data, cellLoc='center',
                         loc='center', colWidths=[0.25, 0.25, 0.25, 0.25])
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1, 2.5)

# Style header
for i in range(4):
    table[(0, i)].set_facecolor('#34495e')
    table[(0, i)].set_text_props(weight='bold', color='white')

# Alternate row colors
for i in range(1, len(table_data)):
    for j in range(4):
        if i % 2 == 0:
            table[(i, j)].set_facecolor('#ecf0f1')

axes[1, 1].set_title('Statistical Comparison', fontsize=14, fontweight='bold', pad=20)

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_12_fraud_transaction_amounts.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 2 complete: Transaction Amount Analysis")
print(f"  • Normal avg: €{normal_amounts.mean():.2f}")
print(f"  • Fraud avg: €{fraud_amounts.mean():.2f}")
print(f"  • Key insight: {'Fraud amounts are HIGHER' if fraud_amounts.mean() > normal_amounts.mean() else 'Fraud amounts are LOWER'}")
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_29608\3529222299.py:39: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = axes[1, 0].boxplot(box_data,
# ✓ Visualization 2 complete: Transaction Amount Analysis
#   • Normal avg: €88.29
#   • Fraud avg: €122.21
#   • Key insight: Fraud amounts are HIGHER

# %%
fig, axes = plt.subplots(3, 1, figsize=(18, 14))
fig.suptitle('Temporal Patterns: When Does Fraud Occur?',
             fontsize=18, fontweight='bold', y=0.995)

# Convert time to hours
fraud_data['Hour'] = (fraud_data['Time'] / 3600) % 24

# Separate by class
normal_time = fraud_data[fraud_data['Class'] == 0]
fraud_time = fraud_data[fraud_data['Class'] == 1]

# Panel 1: Normal Transactions by Hour
axes[0].hist(normal_time['Hour'], bins=24, color='#3498db',
             edgecolor='black', alpha=0.7, range=(0, 24))
axes[0].set_title('Normal Transactions: Distribution by Hour of Day',
                  fontsize=14, fontweight='bold')
axes[0].set_xlabel('Hour of Day (24-hour format)', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Number of Transactions', fontsize=12, fontweight='bold')
axes[0].grid(alpha=0.3, axis='y')
axes[0].set_xlim(0, 24)
axes[0].set_xticks(range(0, 25, 2))

# Add average line
avg_normal = len(normal_time) / 24
axes[0].axhline(avg_normal, color='red', linestyle='--', linewidth=2,
                label=f'Average: {avg_normal:.0f} trans/hour', alpha=0.7)
axes[0].legend(fontsize=10)

# Panel 2: Fraudulent Transactions by Hour
axes[1].hist(fraud_time['Hour'], bins=24, color='#e74c3c',
             edgecolor='black', alpha=0.7, range=(0, 24))
axes[1].set_title('Fraudulent Transactions: Distribution by Hour of Day',
                  fontsize=14, fontweight='bold')
axes[1].set_xlabel('Hour of Day (24-hour format)', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Number of Fraud Cases', fontsize=12, fontweight='bold')
axes[1].grid(alpha=0.3, axis='y')
axes[1].set_xlim(0, 24)
axes[1].set_xticks(range(0, 25, 2))

# Add average line
avg_fraud = len(fraud_time) / 24
axes[1].axhline(avg_fraud, color='darkred', linestyle='--', linewidth=2,
                label=f'Average: {avg_fraud:.1f} fraud/hour', alpha=0.7)
axes[1].legend(fontsize=10)

# Panel 3: Fraud Rate by Hour
hours = range(24)
fraud_rate_by_hour = []
fraud_count_by_hour = []

for hour in hours:
    hour_data = fraud_data[(fraud_data['Hour'] >= hour) & (fraud_data['Hour'] < hour + 1)]
    if len(hour_data) > 0:
        fraud_rate = hour_data['Class'].mean() * 100
        fraud_count = hour_data['Class'].sum()
    else:
        fraud_rate = 0
        fraud_count = 0
    fraud_rate_by_hour.append(fraud_rate)
    fraud_count_by_hour.append(fraud_count)

# Create bar chart with color gradient
colors_gradient = plt.cm.RdYlGn_r(np.array(fraud_rate_by_hour) / max(fraud_rate_by_hour))
bars = axes[2].bar(hours, fraud_rate_by_hour, color=colors_gradient,
                   edgecolor='black', linewidth=1)

axes[2].set_title('Fraud Rate by Hour of Day (Most Dangerous Times)',
                  fontsize=14, fontweight='bold')
axes[2].set_xlabel('Hour of Day (24-hour format)', fontsize=12, fontweight='bold')
axes[2].set_ylabel('Fraud Rate (%)', fontsize=12, fontweight='bold')
axes[2].grid(alpha=0.3, axis='y')
axes[2].set_xlim(-0.5, 23.5)
axes[2].set_xticks(range(0, 24, 2))

# Add average fraud rate line
avg_fraud_rate = fraud_data['Class'].mean() * 100
axes[2].axhline(avg_fraud_rate, color='red', linestyle='--', linewidth=2.5,
                label=f'Overall Avg: {avg_fraud_rate:.3f}%', alpha=0.8)
axes[2].legend(fontsize=11)

# Highlight peak fraud hours
max_fraud_hour = fraud_rate_by_hour.index(max(fraud_rate_by_hour))
axes[2].text(max_fraud_hour, max(fraud_rate_by_hour) + 0.01,
             f'Peak: {max(fraud_rate_by_hour):.3f}%\n@ {max_fraud_hour}:00',
             ha='center', fontweight='bold', fontsize=10,
             bbox=dict(boxstyle='round', facecolor='yellow', alpha=0.9))

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_13_fraud_temporal_patterns.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 3 complete: Time-Based Patterns")
print(f"  • Peak fraud hour: {max_fraud_hour}:00")
print(f"  • Peak fraud rate: {max(fraud_rate_by_hour):.3f}%")
# Out:
# ✓ Visualization 3 complete: Time-Based Patterns
#   • Peak fraud hour: 2:00
#   • Peak fraud rate: 1.713%

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 8))
fig.suptitle('Feature Correlations: Understanding Anonymized Variables',
             fontsize=18, fontweight='bold', y=0.98)

# Select V features (first 14 for readability)
v_features = [f'V{i}' for i in range(1, 15)]

# Panel 1: Correlation with Class (Target)
correlations_with_class = []
for feature in v_features:
    corr = fraud_data[feature].corr(fraud_data['Class'])
    correlations_with_class.append(corr)

# Create bar chart
colors_corr = ['#2ecc71' if c < 0 else '#e74c3c' for c in correlations_with_class]
bars = axes[0].barh(range(len(v_features)), correlations_with_class,
                    color=colors_corr, edgecolor='black', linewidth=1.5)

axes[0].set_yticks(range(len(v_features)))
axes[0].set_yticklabels(v_features, fontsize=10)
axes[0].set_title('Feature Correlation with Fraud (Class)',
                  fontsize=14, fontweight='bold')
axes[0].set_xlabel('Correlation Coefficient', fontsize=12, fontweight='bold')
axes[0].axvline(0, color='black', linewidth=1.5)
axes[0].grid(alpha=0.3, axis='x')

# Add value labels
for i, (feature, corr) in enumerate(zip(v_features, correlations_with_class)):
    x_pos = corr + (0.01 if corr > 0 else -0.01)
    ha = 'left' if corr > 0 else 'right'
    axes[0].text(x_pos, i, f'{corr:.3f}', va='center',
                 ha=ha, fontweight='bold', fontsize=9)

# Highlight strongest correlations
max_corr_idx = np.argmax(np.abs(correlations_with_class))
axes[0].text(0.02, 0.98,
             f'Strongest predictor:\n{v_features[max_corr_idx]}\n(r = {correlations_with_class[max_corr_idx]:.3f})',
             transform=axes[0].transAxes, fontsize=11, fontweight='bold',
             verticalalignment='top', bbox=dict(boxstyle='round', facecolor='yellow', alpha=0.9))

# Panel 2: Feature correlation matrix (heatmap)
feature_subset = ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'Amount', 'Class']
corr_matrix = fraud_data[feature_subset].corr()

sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm',
            center=0, square=True, linewidths=2,
            cbar_kws={"shrink": 0.8, "label": "Correlation"},
            annot_kws={'fontsize': 8}, ax=axes[1], vmin=-1, vmax=1)

axes[1].set_title('Feature Correlation Matrix (V1-V10 + Amount + Class)',
                  fontsize=14, fontweight='bold', pad=15)
plt.setp(axes[1].get_xticklabels(), rotation=45, ha='right', fontsize=9)
plt.setp(axes[1].get_yticklabels(), rotation=0, fontsize=9)

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_14_fraud_feature_correlations.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 4 complete: Feature Correlations")
print(f"  • Strongest predictor: {v_features[max_corr_idx]} (r = {correlations_with_class[max_corr_idx]:.3f})")
# Out:
# ✓ Visualization 4 complete: Feature Correlations
#   • Strongest predictor: V14 (r = -0.303)

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 12))
fig.suptitle('Fraud Detection: The Precision-Recall Challenge',
             fontsize=18, fontweight='bold', y=0.995)

# Simulate detection scenarios based on Amount threshold
thresholds = np.linspace(0, 500, 100)
true_positives = []
false_positives = []
true_negatives = []
false_negatives = []
precision_scores = []
recall_scores = []

for threshold in thresholds:
    # Simulate: Flag as fraud if amount > threshold
    predictions = (fraud_data['Amount'] > threshold).astype(int)

    tp = ((predictions == 1) & (fraud_data['Class'] == 1)).sum()
    fp = ((predictions == 1) & (fraud_data['Class'] == 0)).sum()
    tn = ((predictions == 0) & (fraud_data['Class'] == 0)).sum()
    fn = ((predictions == 0) & (fraud_data['Class'] == 1)).sum()

    true_positives.append(tp)
    false_positives.append(fp)
    true_negatives.append(tn)
    false_negatives.append(fn)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0

    precision_scores.append(precision)
    recall_scores.append(recall)

# Panel 1: Precision vs Recall Trade-off
axes[0, 0].plot(thresholds, precision_scores, 'b-', linewidth=2.5,
                label='Precision', marker='o', markersize=3)
axes[0, 0].plot(thresholds, recall_scores, 'r-', linewidth=2.5,
                label='Recall', marker='s', markersize=3)
axes[0, 0].set_title('Precision vs Recall Trade-off\n(Amount-based threshold)',
                     fontsize=14, fontweight='bold')
axes[0, 0].set_xlabel('Amount Threshold (€)', fontsize=12, fontweight='bold')
axes[0, 0].set_ylabel('Score', fontsize=12, fontweight='bold')
axes[0, 0].legend(fontsize=11, loc='best')
axes[0, 0].grid(alpha=0.3)
axes[0, 0].set_xlim(0, 500)
axes[0, 0].set_ylim(0, 1.05)

# Panel 2: True Positives vs False Positives
axes[0, 1].plot(thresholds, true_positives, 'g-', linewidth=2.5,
                label='True Positives (Caught Fraud)', marker='o', markersize=3)
axes[0, 1].plot(thresholds, false_positives, 'orange', linestyle='-', linewidth=2.5,
                label='False Positives (False Alarms)', marker='s', markersize=3)
axes[0, 1].set_title('Detection Trade-off: Caught Fraud vs False Alarms',
                     fontsize=14, fontweight='bold')
axes[0, 1].set_xlabel('Amount Threshold (€)', fontsize=12, fontweight='bold')
axes[0, 1].set_ylabel('Number of Cases', fontsize=12, fontweight='bold')
axes[0, 1].legend(fontsize=11, loc='best')
axes[0, 1].grid(alpha=0.3)
axes[0, 1].set_xlim(0, 500)

# Panel 3: F1-Score (Harmonic mean of Precision and Recall)
f1_scores = []
for p, r in zip(precision_scores, recall_scores):
    f1 = 2 * (p * r) / (p + r) if (p + r) > 0 else 0
    f1_scores.append(f1)

axes[1, 0].plot(thresholds, f1_scores, 'purple', linewidth=3,
                marker='o', markersize=4)
axes[1, 0].set_title('F1-Score: Finding the Optimal Balance',
                     fontsize=14, fontweight='bold')
axes[1, 0].set_xlabel('Amount Threshold (€)', fontsize=12, fontweight='bold')
axes[1, 0].set_ylabel('F1-Score', fontsize=12, fontweight='bold')
axes[1, 0].grid(alpha=0.3)
axes[1, 0].set_xlim(0, 500)
axes[1, 0].set_ylim(0, max(f1_scores) * 1.1)

# Highlight optimal F1
max_f1_idx = np.argmax(f1_scores)
optimal_threshold = thresholds[max_f1_idx]
max_f1 = f1_scores[max_f1_idx]

axes[1, 0].axvline(optimal_threshold, color='red', linestyle='--', linewidth=2,
                   alpha=0.7, label=f'Optimal: €{optimal_threshold:.0f}')
axes[1, 0].scatter([optimal_threshold], [max_f1], s=200, c='red',
                   marker='*', edgecolors='black', linewidth=2, zorder=5)
axes[1, 0].text(optimal_threshold + 20, max_f1,
                f'F1 = {max_f1:.3f}\n@ €{optimal_threshold:.0f}',
                fontweight='bold', fontsize=10,
                bbox=dict(boxstyle='round', facecolor='yellow', alpha=0.9))
axes[1, 0].legend(fontsize=11)

# Panel 4: Confusion Matrix at Optimal Threshold
optimal_predictions = (fraud_data['Amount'] > optimal_threshold).astype(int)
tp_opt = ((optimal_predictions == 1) & (fraud_data['Class'] == 1)).sum()
fp_opt = ((optimal_predictions == 1) & (fraud_data['Class'] == 0)).sum()
tn_opt = ((optimal_predictions == 0) & (fraud_data['Class'] == 0)).sum()
fn_opt = ((optimal_predictions == 0) & (fraud_data['Class'] == 1)).sum()

confusion_matrix = np.array([[tn_opt, fp_opt], [fn_opt, tp_opt]])

sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Blues',
            cbar=False, square=True, linewidths=3, linecolor='black',
            annot_kws={'fontsize': 16, 'fontweight': 'bold'}, ax=axes[1, 1])

axes[1, 1].set_title(f'Confusion Matrix at Optimal Threshold (€{optimal_threshold:.0f})',
                     fontsize=14, fontweight='bold', pad=15)
axes[1, 1].set_xlabel('Predicted Label', fontsize=12, fontweight='bold')
axes[1, 1].set_ylabel('Actual Label', fontsize=12, fontweight='bold')
axes[1, 1].set_xticklabels(['Normal', 'Fraud'], fontsize=11)
axes[1, 1].set_yticklabels(['Normal', 'Fraud'], fontsize=11, rotation=0)

# Add metrics
accuracy = (tp_opt + tn_opt) / len(fraud_data)
precision_opt = tp_opt / (tp_opt + fp_opt) if (tp_opt + fp_opt) > 0 else 0
recall_opt = tp_opt / (tp_opt + fn_opt) if (tp_opt + fn_opt) > 0 else 0

metrics_text = f'Accuracy: {accuracy:.3f}\nPrecision: {precision_opt:.3f}\nRecall: {recall_opt:.3f}\nF1-Score: {max_f1:.3f}'
axes[1, 1].text(1.05, 0.5, metrics_text, transform=axes[1, 1].transAxes,
                fontsize=11, fontweight='bold', verticalalignment='center',
                bbox=dict(boxstyle='round', facecolor='lightgreen', alpha=0.9))

plt.tight_layout()

# Save the figure
plt.savefig('results/exploration/day1_15_fraud_detection_performance.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Visualization 5 complete: Detection Performance Simulation")
print(f"  • Optimal threshold: €{optimal_threshold:.2f}")
print(f"  • Best F1-Score: {max_f1:.3f}")
print(f"  • True Positives: {tp_opt:,} | False Positives: {fp_opt:,}")
print(f"  • This shows the fundamental challenge in fraud detection!")
# Out:
# ✓ Visualization 5 complete: Detection Performance Simulation
#   • Optimal threshold: €500.00
#   • Best F1-Score: 0.007
#   • True Positives: 35 | False Positives: 9,107
#   • This shows the fundamental challenge in fraud detection!
